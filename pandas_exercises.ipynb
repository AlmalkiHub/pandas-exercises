# %% [markdown]
# <a href="https://colab.research.google.com/github/AlmalkiHub/pandas-exercises/blob/main/pandas_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Practice
# ## Solved by `Ali Almalki`
#
# This notebook is dedicated to practicing different tasks with pandas.

# %%
# Import pandas
import pandas as pd

# %%
# Create a series of three different colours
colours = pd.Series(['red', 'green', 'blue'])

# %%
# View the series of different colours
colours
# Out:
# 0      red
# 1    green
# 2     blue
# dtype: object

# %%
# Create a series of three different car types and view it
cars = pd.Series(['BMW', 'Kona', 'Gelly'])
cars
# Out:
# 0      BMW
# 1     Kona
# 2    Gelly
# dtype: object

# %%
print(colours,'\n')
print(cars)
# Out:
# 0      red
# 1    green
# 2     blue
# dtype: object
#
# 0      BMW
# 1     Kona
# 2    Gelly
# dtype: object

# %%
# Combine the Series of cars and colours into a DataFrame
pd.DataFrame({'Colour':colours,
              'Car': cars})
# Out:
#   Colour    Car
# 0    red    BMW
# 1  green   Kona
# 2   blue  Gelly

# %%
# Import "../data/car-sales.csv" and turn it into a DataFrame
df = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales.csv')
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Check data shape
df.shape
# Out:
# (10, 5)

# %%
# Check data info 
print(df.info())
print(df.describe)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes
# None
# <bound method NDFrame.describe of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# ...

# %%
# Export the DataFrame you created to a .csv file
df.to_csv('car_sales.csv')

# %%
# Find the different datatypes of the car data DataFrame
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Describe your current car sales DataFrame using describe()
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# Get information about your DataFrame using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
# Create a Series of different numbers and find the mean of them
nums = pd.Series([42, 102, 150])
print(nums)
print('Average = ', nums.mean())
# Out:
# 0     42
# 1    102
# 2    150
# dtype: int64
# Average =  98.0

# %%
# Create a Series of different numbers and find the sum of them
nums = pd.Series([78, 55, 102, 2005, 1989])
print(nums)
print('Total = ', nums.sum())
# Out:
# 0      78
# 1      55
# 2     102
# 3    2005
# 4    1989
# dtype: int64
# Total =  4229

# %%
# List out all the column names of the car sales DataFrame
df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# Find the length of the car sales DataFrame
print(len(df))
print(df.shape)
# Out:
# 10
# (10, 5)

# %%
# Show the first 5 rows of the car sales DataFrame
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame
df.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame
df.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
df.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
df.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
df['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
df['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
# Select the rows with over 100,000 kilometers on the Odometer
df['Odometer (KM)'] > 100000
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Odometer (KM), dtype: bool

# %%
# Create a crosstab of the Make and Doors columns
pd.crosstab(df['Make'], df['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
df.groupby('Make').mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import Matplotlib and create a plot of the Odometer column
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(df['Odometer (KM)']);

# %%
# Create a histogram of the Odometer column using hist()
plt.hist(df['Odometer (KM)']);

# %%
# Try to plot the Price column using plot()
plt.plot(df['Price']);

# %%
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Change Price column type from string (Object) to integer
df['Price'] = df['Price'].str.replace('[\$\,]|\.\d*', '').astype(int)
df.dtypes
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
# Plot again and see how it goes now 
plt.plot(df['Price']);

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500

# %%
# Check the changes to the price column
df['Price']
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int64

# %%
# Change the datatype of the Price column to integers
# df['Price'] = df['Price'].astype(int)

# %%
# Lower the strings of the Make column
df['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %% [markdown]
# If you check the car sales DataFrame, you'll notice the Make column hasn't been lowered.
#
# How could you make these changes permanent?
#
# Try it out.

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500

# %%
# Make lowering the case of the Make column permanent
# df = df['Make'].str.lower()
# df.head()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# Name: Make, dtype: object

# %%
# Check the car sales DataFrame
df.head()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# Name: Make, dtype: object

# %% [markdown]
# Notice how the Make column stays lowered after reassigning.
#
# Now let's deal with missing data.

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-missing-data.csv")
dfnew = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-missing-data.csv')


# Check out the new DataFrame
dfnew.head()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %% [markdown]
# Notice the missing values are represented as `NaN` in pandas DataFrames.
#
# Let's try fill them.

# %%
# Check how many null values we have
dfnew.isnull().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
# Fill the Odometer column missing values with the mean of the column inplace
dfnew['Odometer'].fillna(dfnew['Odometer'].mean(),
                      inplace=True)

# %%
dfnew.isnull().sum()
# Out:
# Make        1
# Colour      1
# Odometer    0
# Doors       1
# Price       2
# dtype: int64

# %%
# View the car sales missing DataFrame and verify the changes
dfnew.head()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500

# %%
# Remove the rest of the missing data inplace
dfnew.dropna(inplace=True)

# %%
# Verify the missing values are removed by viewing the DataFrame
print(dfnew.isnull().sum())
print(dfnew.head())
# Out:
# Make        0
# Colour      0
# Odometer    0
# Doors       0
# Price       0
# dtype: int64
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500

# %% [markdown]
# We'll now start to add columns to our DataFrame.

# %%
# Create a "Seats" column where every row has a value of 5
dfnew['Seats'] = 5
dfnew
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000      5
# 1   Honda    Red   87899.000000    4.0   $5,000      5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5
# 3     BMW  Black   11179.000000    5.0  $22,000      5
# 4  Nissan  White  213095.000000    4.0   $3,500      5
# 5  Toyota  Green   92302.666667    4.0   $4,500      5

# %%
len(dfnew)
# Out:
# 6

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame
import numpy as np
dfnew['Engine Size'] = np.random.uniform(1.3, 4.5, size=(6, ))
dfnew
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   $4,000      5     4.419893
# 1   Honda    Red   87899.000000    4.0   $5,000      5     4.392774
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5     4.498992
# 3     BMW  Black   11179.000000    5.0  $22,000      5     2.947486
# 4  Nissan  White  213095.000000    4.0   $3,500      5     2.187769
# 5  Toyota  Green   92302.666667    4.0   $4,500      5     3.310349

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
dfnew['Price Per (KM)'] = 2.3
dfnew
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size  \
# 0  Toyota  White  150043.000000    4.0   $4,000      5     4.419893
# 1   Honda    Red   87899.000000    4.0   $5,000      5     4.392774
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5     4.498992
# 3     BMW  Black   11179.000000    5.0  $22,000      5     2.947486
# 4  Nissan  White  213095.000000    4.0   $3,500      5     2.187769
# 5  Toyota  Green   92302.666667    4.0   $4,500      5     3.310349
#
#    price per km  Price Per (KM)
# 0           2.3             2.3
# 1           2.3             2.3
# 2           2.3             2.3
# 3           2.3             2.3
# 4           2.3             2.3
# 5           2.3             2.3

# %%
# Remove the last column you added using .drop()
dfnew = dfnew.drop('Price Per (KM)', axis=1)
dfnew = dfnew.drop('price per km', axis=1)

dfnew.head()
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   $4,000      5     4.419893
# 1   Honda    Red   87899.000000    4.0   $5,000      5     4.392774
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5     4.498992
# 3     BMW  Black   11179.000000    5.0  $22,000      5     2.947486
# 4  Nissan  White  213095.000000    4.0   $3,500      5     2.187769

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
shuffled_df = dfnew.sample(frac=1)
shuffled_df
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   $4,000      5     4.419893
# 5  Toyota  Green   92302.666667    4.0   $4,500      5     3.310349
# 1   Honda    Red   87899.000000    4.0   $5,000      5     4.392774
# 4  Nissan  White  213095.000000    4.0   $3,500      5     2.187769
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5     4.498992
# 3     BMW  Black   11179.000000    5.0  $22,000      5     2.947486

# %% [markdown]
# Notice how the index numbers get moved around. The [`sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) function is a great way to get random samples from your DataFrame. It's also another great way to shuffle the rows by setting `frac=1`.

# %%
# Reset the indexes of the shuffled DataFrame
shuffled_df.reset_index()
# Out:
#    index    Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0      0  Toyota  White  150043.000000    4.0   $4,000      5     4.419893
# 1      5  Toyota  Green   92302.666667    4.0   $4,500      5     3.310349
# 2      1   Honda    Red   87899.000000    4.0   $5,000      5     4.392774
# 3      4  Nissan  White  213095.000000    4.0   $3,500      5     2.187769
# 4      2  Toyota   Blue   92302.666667    3.0   $7,000      5     4.498992
# 5      3     BMW  Black   11179.000000    5.0  $22,000      5     2.947486

# %% [markdown]
# Notice the index numbers have been changed to have order (start from 0).

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame
shuffled_df['Odometer'] = shuffled_df['Odometer'].apply(lambda x: x/1.6)
shuffled_df
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White   93776.875000    4.0   $4,000      5     4.419893
# 5  Toyota  Green   57689.166667    4.0   $4,500      5     3.310349
# 1   Honda    Red   54936.875000    4.0   $5,000      5     4.392774
# 4  Nissan  White  133184.375000    4.0   $3,500      5     2.187769
# 2  Toyota   Blue   57689.166667    3.0   $7,000      5     4.498992
# 3     BMW  Black    6986.875000    5.0  $22,000      5     2.947486

# %%
# Change the title of the Odometer (KM) to represent miles instead of kilometers
shuffled_df = shuffled_df.rename(columns={'Odometer': 'Odometer (Miles)'})
shuffled_df
# Out:
#      Make Colour  Odometer (Miles)  Doors    Price  Seats  Engine Size
# 0  Toyota  White      93776.875000    4.0   $4,000      5     4.419893
# 5  Toyota  Green      57689.166667    4.0   $4,500      5     3.310349
# 1   Honda    Red      54936.875000    4.0   $5,000      5     4.392774
# 4  Nissan  White     133184.375000    4.0   $3,500      5     2.187769
# 2  Toyota   Blue      57689.166667    3.0   $7,000      5     4.498992
# 3     BMW  Black       6986.875000    5.0  $22,000      5     2.947486

# %% [markdown]
# ### References:
#
# * [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/)
# * [Exercise Source](https://github.com/mrdbourke/zero-to-mastery-ml/blob/master/section-2-data-science-and-ml-tools/pandas-exercises.ipynb)
# * [10-minutes to pandas section](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)
# * [Top questions and answers on Stack Overflow for pandas](https://stackoverflow.com/questions/tagged/pandas?sort=MostVotes&edited=true)
# * Pandas [.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [.iloc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html).
